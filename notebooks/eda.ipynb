# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('/content/archive (13).zip')
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
df.shape
# Out:
# (1470, 35)

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %%
df.nunique().sort_values()
# Out:
# EmployeeCount                  1
# Over18                         1
# StandardHours                  1
# Attrition                      2
# OverTime                       2
# PerformanceRating              2
# Gender                         2
# BusinessTravel                 3
# Department                     3
# MaritalStatus                  3
# RelationshipSatisfaction       4
# StockOptionLevel               4
# JobSatisfaction                4
# EnvironmentSatisfaction        4
# JobInvolvement                 4
# WorkLifeBalance                4
# Education                      5
# JobLevel                       5
# EducationField                 6
# TrainingTimesLastYear          7
# JobRole                        9
# NumCompaniesWorked            10
# PercentSalaryHike             15
# YearsSinceLastPromotion       16
# YearsWithCurrManager          18
# YearsInCurrentRole            19
# DistanceFromHome              29
# YearsAtCompany                37
# ...

# %%
df.drop(
    ['EmployeeCount', 'EmployeeNumber', 'Over18', 'StandardHours' , 'Over18'],
    axis=1,
    inplace=True
)

# %%
X = df.drop('Attrition', axis=1)
y = df['Attrition']

# %%
num_cols = df.select_dtypes(include=['int64', 'float64']).columns.tolist()
cat_cols = df.select_dtypes(include=['object']).columns.tolist()

# %%
num_cols
# Out:
# ['Age',
#  'DailyRate',
#  'DistanceFromHome',
#  'Education',
#  'EnvironmentSatisfaction',
#  'HourlyRate',
#  'JobInvolvement',
#  'JobLevel',
#  'JobSatisfaction',
#  'MonthlyIncome',
#  'MonthlyRate',
#  'NumCompaniesWorked',
#  'PercentSalaryHike',
#  'PerformanceRating',
#  'RelationshipSatisfaction',
#  'StockOptionLevel',
#  'TotalWorkingYears',
#  'TrainingTimesLastYear',
#  'WorkLifeBalance',
#  'YearsAtCompany',
#  'YearsInCurrentRole',
#  'YearsSinceLastPromotion',
#  'YearsWithCurrManager']

# %%
cat_cols
# Out:
# ['Attrition',
#  'BusinessTravel',
#  'Department',
#  'EducationField',
#  'Gender',
#  'JobRole',
#  'MaritalStatus',
#  'OverTime']

# %%
df['Attrition'].value_counts(normalize=True)
# Out:
# Attrition
# No     0.838776
# Yes    0.161224
# Name: proportion, dtype: float64

# %% [markdown]
# The target variable is imbalanced, indicating the need for recall-focused
# evaluation and imbalance handling during modeling.

# %%
sns.boxplot(x = 'Attrition' , y = 'YearsAtCompany' , data = df)
plt.title('Attrition vs years at company')
plt.show()

# %% [markdown]
# Employees with lower tenure at the company show higher attrition,
# making YearsAtCompany a strong predictive feature.

# %%
sns.boxplot(x='Attrition', y='YearsInCurrentRole', data=df)
plt.show()

# %% [markdown]
# - Employees who left the company have fewer years in their current role.
# - Employees who stayed have spent more time in the same role.

# %%
df['YearsSinceLastPromotion']
# Out:
# 0       0
# 1       1
# 2       0
# 3       3
# 4       2
#        ..
# 1465    0
# 1466    1
# 1467    0
# 1468    0
# 1469    1
# Name: YearsSinceLastPromotion, Length: 1470, dtype: int64

# %%
df['OverTime']
# Out:
# 0       Yes
# 1        No
# 2       Yes
# 3       Yes
# 4        No
#        ...
# 1465     No
# 1466     No
# 1467    Yes
# 1468     No
# 1469     No
# Name: OverTime, Length: 1470, dtype: object

# %%
sns.countplot(x='OverTime', hue='Attrition', data=df)
plt.show()

# %% [markdown]
# Employees who work overtime show higher attrition compared to those who do not.
# OverTime is a strong and important feature for predicting employee attrition.

# %%
sns.countplot(x='WorkLifeBalance',hue='Attrition' , data = df)
plt.show()

# %% [markdown]
# Employees with poor work-life balance show higher attrition, while those with better balance tend to stay.
# WorkLifeBalance is an important feature for predicting attrition.

# %%
sns.countplot(x = 'JobSatisfaction' , hue = 'Attrition' , data=df)
plt.show()

# %% [markdown]
# Employees with lower job satisfaction show higher attrition, while those with higher satisfaction tend to stay.
# JobSatisfaction is an important feature for predicting employee attrition.

# %%
sns.countplot(x = 'JobInvolvement' , hue = 'Attrition' , data=df)
plt.show()

# %% [markdown]
# Employees with lower job involvement show higher attrition, while higher involvement is associated with lower attrition.
# JobInvolvement is an important feature for predicting attrition.

# %%
sns.boxplot(x='Attrition', y='MonthlyIncome', data=df)
plt.show()

# %% [markdown]
# Employees who left the company have lower monthly income compared to those who stayed.
# MonthlyIncome is an important feature for predicting employee attrition.

# %%
sns.boxplot(x='Attrition', y='MonthlyIncome', data=df)
plt.show()

# %% [markdown]
# Employees who left the company have lower monthly income compared to those who stayed.
# MonthlyIncome is an important feature for attrition prediction.

# %%
sns.countplot(x='JobLevel', hue='Attrition', data=df)
plt.show()

# %% [markdown]
# Employee  who left the company was not satisfied by their job level . This feature clearly shows that less job level more attrition.

# %%
sns.boxplot(x='Attrition', y='Age', data=df)
plt.show()

# %% [markdown]
# Employees who left the company are generally younger, while older employees tend to stay.
# Age is an important feature for predicting employee attrition.

# %%
sns.boxplot(x='Attrition' , y='DistanceFromHome' , data=df)
plt.show()

# %% [markdown]
# Employees who live farther from work are more likely to leave.
# DistanceFromHome is a moderately important feature.

# %%
sns.countplot(y='JobRole', hue='Attrition', data=df)
plt.title('Attrition by JobRole')
plt.show()

# %% [markdown]
# Attrition varies across job roles, with some roles showing higher attrition than others.
# JobRole is an important feature for predicting employee attrition.

# %%
sns.countplot(x='BusinessTravel', hue='Attrition', data=df)
plt.title('Attrition by Business Travel')
plt.show()

# %% [markdown]
# Employees who travel frequently for work show higher attrition.
# BusinessTravel is an important feature for attrition prediction.

# %% [markdown]
# ## EDA Summary – Employee Attrition
#
# Attrition is strongly influenced by **OverTime, MonthlyIncome, JobSatisfaction, JobInvolvement, WorkLifeBalance, Age, JobRole, and BusinessTravel**.
#
# Moderate impact is observed from **YearsAtCompany, YearsInCurrentRole, and DistanceFromHome**.
#
# Features such as **EnvironmentSatisfaction, YearsSinceLastPromotion, PercentSalaryHike, and Gender** show weak or no clear relationship with attrition.
#
# These insights are used for feature selection in model training.
